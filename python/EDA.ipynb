# %%
# !ls "../raw_custom_data/AWS_AI_Preliminary_Contest/data/04003906/Camera1/1"
# Out:
# 1.png  13.png 17.png 20.png 24.png 28.png 31.png 35.png 39.png 6.png
# 1.xml  13.xml 17.xml 20.xml 24.xml 28.xml 31.xml 35.xml 39.xml 6.xml
# 10.png 14.png 18.png 21.png 25.png 29.png 32.png 36.png 4.png  7.png
# 10.xml 14.xml 18.xml 21.xml 25.xml 29.xml 32.xml 36.xml 4.xml  7.xml
# 11.png 15.png 19.png 22.png 26.png 3.png  33.png 37.png 40.png 8.png
# 11.xml 15.xml 19.xml 22.xml 26.xml 3.xml  33.xml 37.xml 40.xml 8.xml
# 12.png 16.png 2.png  23.png 27.png 30.png 34.png 38.png 5.png  9.png
# 12.xml 16.xml 2.xml  23.xml 27.xml 30.xml 34.xml 38.xml 5.xml  9.xml

# %%
from glob import glob
base_path = '../raw_custom_data/AWS_AI_Preliminary_Contest/data'

types = ('png', 'jpg') # the tuple of file types
imgs = []
for t in types:
    imgs.extend(glob(base_path + '/*/*/*/*.{}'.format(t)))

xmls = glob(base_path + '/*/*/*/*.xml')

# assert len(imgs) == len(xmls),"dataset issue: # of images = {} , and # of xml files = {}".format(len(imgs),len(xmls))

# %%
xmls[0]
# Out:
# '../raw_custom_data/AWS_AI_Preliminary_Contest/data/4710126100923/Camera1/9/8.xml'

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
# %matplotlib inline

# %%
def removeAxeEdge(ax):
    for loc, spine in ax.spines.items():
        spine.set_color('none')
        
    ax.yaxis.set_ticks([])
    ax.xaxis.set_ticks([])

# %%
import os

def get_xml_from_image(img_path):

    p,f = os.path.split(img_path)
    name,ext = f.split('.')
    return os.path.join(p, name + '.xml')

# %%
get_xml_from_image("../raw_custom_data/AWS_AI_Preliminary_Contest/data/04003906/Camera1/1/13.png")
# Out:
# '../raw_custom_data/AWS_AI_Preliminary_Contest/data/04003906/Camera1/1/13.xml'

# %%
import re
from tqdm import tqdm
widths = []
heights = []
lefts = []
bottoms = []
paths = []

for idx in tqdm(range(len(imgs))):
    
    paths.append(imgs[idx])
    
    xml = get_xml_from_image(imgs[idx])
    with open(xml, 'r') as f:
        text = f.read()
    # print("text= ", text)
    p_name = re.compile("<name>\s*(.*)\s*</name>")
    result = p_name.search(text)
    name = result.group(1)

    p_xmin = re.compile("<xmin>\s*(.*)\s*</xmin>")
    result = p_xmin.search(text)
    xmin = result.group(1)

    p_xmax = re.compile("<xmax>\s*(.*)\s*</xmax>")
    result = p_xmax.search(text)
    xmax = result.group(1)

    p_ymin = re.compile("<ymin>\s*(.*)\s*</ymin>")
    result = p_ymin.search(text)
    ymin = result.group(1)

    p_ymax = re.compile("<ymax>\s*(.*)\s*</ymax>")
    result = p_ymax.search(text)
    ymax = result.group(1)

    p_width = re.compile("<width>\s*(.*)\s*</width>")
    result = p_width.search(text)
    img_width = result.group(1)

    p_height = re.compile("<height>\s*(.*)\s*</height>")
    result = p_height.search(text)
    img_height = result.group(1)

    bottom = float(ymax) / float(img_height)
    left = float(xmin) / float(img_width)
    width = abs(float(xmax) - float(xmin)) / float(img_width)
    height = abs(float(ymax) - float(ymin)) / float(img_height)
    img_height = float(img_height)
    img_width = float(img_width)
    
    
    widths.append(width)
    heights.append(height)
    lefts.append(left)
    bottoms.append(bottom)
# Out:
# 100%|██████████| 29827/29827 [00:10<00:00, 2899.03it/s]

# %%
# import numpy as np
# widths = np.array(widths)

# tot = np.where((widths > 0) & (widths < 1))[0].shape[0]
# np.where((widths > 0.1) & (widths < 0.2))[0].shape[0] /tot

# %%
from matplotlib.pyplot import hist
n,bins,patchs = hist(widths, bins=100, range=(0.02,0.6))

# %%
from matplotlib.pyplot import hist
n,bins,patchs = hist(heights, bins=100, range=(0.02,0.6))

# %%
idx = 10

fig = plt.figure(figsize=(16,8))
ax = fig.add_axes([0,0,1,1])
removeAxeEdge(ax)

# axes coordinates are 0,0 is bottom left and 1,1 is upper right
p = patches.Rectangle((lefts[idx], 1.0 - bottoms[idx]), widths[idx], heights[idx], fill=False, transform=ax.transAxes, clip_on=False, color='r', ls = '--', lw = 2)
ax.add_patch(p)


img = mpimg.imread(imgs[idx])

plt.imshow(img)
print('width , heigh = {:.0f} , {:.0f} . Path = {}'.format(widths[idx] * img_width, heights[idx] * img_height, paths[idx]))
# Out:
# width , heigh = 154 , 182 . Path = ../raw_custom_data/AWS_AI_Preliminary_Contest/data/4710126100923/Camera1/9/39.png

# %% [markdown]
# # Test Pre-processed Result

# %%
from glob import glob
base_path = '../data/custom/'

types = ('png', 'jpg') # the tuple of file types
imgs = []
for t in types:
    imgs.extend(glob(base_path + 'images/*.{}'.format(t)))

txts = glob(base_path + 'labels/*.txt')

assert len(imgs) == len(txts),"dataset issue: # of images = {} , and # of xml files = {}".format(len(imgs),len(txts))

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
# %matplotlib inline

# %%
def removeAxeEdge(ax):
    for loc, spine in ax.spines.items():
        spine.set_color('none')
        
    ax.yaxis.set_ticks([])
    ax.xaxis.set_ticks([])

# %%
import os

def get_txt_from_image(img_path):

    p,f = os.path.split(img_path)
    name,ext = f.split('.')
    b,t = os.path.split(p)
    return os.path.join(b, 'labels', name + '.txt')

get_txt_from_image('../data/custom/images/4710126100923_Camera3_9_11.png')
# Out:
# '../data/custom/labels/4710126100923_Camera3_9_11.txt'

# %%
import re
from tqdm import tqdm
widths = []
heights = []
lefts = []
bottoms = []
paths = []

for idx in tqdm(range(len(imgs))):
    
    paths.append(imgs[idx])
    
    txt = get_txt_from_image(imgs[idx])
    with open(txt, 'r') as f:
        text = f.read()
#     print("text= ", text)
#     print(text.split(' '))
    data = text.split(' ')
    if len(data) != 5:
        continue
    lefts.append(float(data[1]) - (float(data[3])/2)) 
    bottoms.append(float(data[2]) + (float(data[4])/2)) 
    widths.append(float(data[3]))
    heights.append(float(data[4]))
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1092.84it/s]

# %%
for idx in range(len(imgs)):

    fig = plt.figure(figsize=(8,4))
    ax = fig.add_axes([0,0,1,1])
    removeAxeEdge(ax)

    # axes coordinates are 0,0 is bottom left and 1,1 is upper right
    p = patches.Rectangle((lefts[idx], 1.0 - bottoms[idx]), widths[idx], heights[idx], fill=False, transform=ax.transAxes, clip_on=False, color='r', ls = '--', lw = 2)
    ax.add_patch(p)

    img = mpimg.imread(imgs[idx])

    plt.imshow(img)
    plt.show()
